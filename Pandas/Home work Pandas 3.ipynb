# %% [markdown]
# 📘Задание 1
#
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
#
# если источник traffic_source равен yandex или google, то в source_type ставится organic
# для источников paid и email из России - ставим ad
# для источников paid и email не из России - ставим other
# все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd

# %%
#Создаю датафрейм df
df = pd.read_csv('visit_log.csv', sep = ';')
df.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
def source_type(df):
    """
    Функция возвращает значение создаваемого столбца source_type в датафрейме по след. правилу:
    - если источник traffic_source равен yandex или google, то в source_type ставится organic
    - для источников paid и email из России - ставится ad
    - для источников paid и email не из России - ставится other
    - для всех остальных вариантов берется значение из traffic_source без изменений
    """
    if df['traffic_source'] in ['yandex','google']:
        return 'organic'
    elif df['traffic_source'] in ['paid','email']:
        if df['region']=='Russia':
            return 'ad'
        else:
            return 'other'
    else:
        return df['traffic_source']

# %%
df['source_type'] = df.apply(source_type, axis=1)
df.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic

# %%
#Просмотр интересующих значений 
df[(df['source_type'] != 'organic')&(df['region'] != 'Russia')&(df['traffic_source']!='yandex')&(df['traffic_source']!='google')]
# Out:
#         timestamp    visit_id                                 url   region  \
# 8      1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867    China
# 10     1549980777  01d448afd9  https://host.ru/a5dda93e70318570c0    India
# 13     1549980792  dd46c3eebb  https://host.ru/3004a8273caeef2867    China
# 14     1549980793  e7ecebbc59  https://host.ru/05e41944dd85a900a6  Belarus
# 15     1549980797  5322fecfc9  https://host.ru/4adc8a29b212051b04  Belarus
# ...           ...         ...                                 ...      ...
# 18921  1550094218  b9723ef95e  https://host.ru/c8d9213a31839f9a3a  Ukraine
# 18925  1550094228  90efa16935  https://host.ru/23c64743ad842b9311  Belarus
# 18927  1550094245  1e0d086733  https://host.ru/c2382eb3d6afc8d0f3  Ukraine
# 18931  1550094269  a7e2dfd759  https://host.ru/ef57543002ce2a0f2a  Belarus
# 18933  1550094288  57e5ba8560  https://host.ru/c2382eb3d6afc8d0f3  Belarus
#
#           user_id traffic_source source_type
# ...

# %% [markdown]
# 📘Задание 2
#
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
#
# Прочитайте содержимое файла с датафрейм
# Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
#Создаю датафрейм df
df_txt = pd.read_csv('URLs.txt')
df_txt.head()
# Out:
#                                                  url
# 0                                            /world/
# 1                                           /latest/
# 2                                      /?updated=top
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %%
#Отбор нужных значений
df_txt.loc[df_txt['url'].str.contains('\/\d{8}-')]
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [84 rows x 1 columns]

# %%
📘Задание 3

Используйте файл с оценками фильмов ml-latest-small/ratings.csv.
Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок.
Под временем жизни понимается разница между максимальным и минимальным значением
столбца timestamp для данного значения userId.

# %%
##Создаю датафрейм df_ratings
df_ratings = pd.read_csv('ml-latest-small/ratings.csv')

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#Создаю датафрейм со всеми пользователями и минимальным и максимальным значением времени
df_min_max = df_ratings[['userId', 'timestamp']].groupby('userId').agg([min, max]).reset_index()
df_min_max
# Out:
#     userId   timestamp
#                    min         max
# 0        1   964980499   965719662
# 1        2  1445714835  1445715340
# 2        3  1306463323  1306464293
# 3        4   945078428  1007574542
# 4        5   847434747   847435337
# ..     ...         ...         ...
# 605    606  1171228846  1368460577
# 606    607   963078392   997847387
# 607    608  1117161730  1189563917
# 608    609   847220802   847221080
# 609    610  1479541963  1495959411
#
# [610 rows x 3 columns]

# %%
#Переименовала столбцы, чтобы избавиться от иерархии в названии
#(при объединении непереименованной таблицы выдается предупреждение)
df_min_max.columns = ['userId', 'timestamp_min', 'timestamp_max']
df_min_max
# Out:
#      userId  timestamp_min  timestamp_max
# 0         1      964980499      965719662
# 1         2     1445714835     1445715340
# 2         3     1306463323     1306464293
# 3         4      945078428     1007574542
# 4         5      847434747      847435337
# ..      ...            ...            ...
# 605     606     1171228846     1368460577
# 606     607      963078392      997847387
# 607     608     1117161730     1189563917
# 608     609      847220802      847221080
# 609     610     1479541963     1495959411
#
# [610 rows x 3 columns]

# %%
#Создаю датафрейм со всеми пользователями и количеством выставленных оценок по каждому пользователю
df_userId = df_ratings[['userId', 'rating']].groupby('userId').count().reset_index()
df_userId.tail()
# Out:
#      userId  rating
# 605     606    1115
# 606     607     187
# 607     608     831
# 608     609      37
# 609     610    1302

# %%
# Создаю датафрейм только с теми пользователями, которые выставили более 100 оценок
df_100 = df_userId.loc[df_userId['rating'] > 100]
df_100
# Out:
#      userId  rating
# 0         1     232
# 3         4     216
# 5         6     314
# 6         7     152
# 9        10     140
# ..      ...     ...
# 604     605     221
# 605     606    1115
# 606     607     187
# 607     608     831
# 609     610    1302
#
# [245 rows x 2 columns]

# %%
#Объединяю таблицу с пользователями,которые выставили более 100 оценок, с таблицей со максимальным и минимальным временем 
df_joined = df_100.merge(df_min_max, on='userId', how='left')
#df_100.loc[pd.isnull(df_100.rating), :]
df_joined
# Out:
#      userId  rating  timestamp_min  timestamp_max
# 0         1     232      964980499      965719662
# 1         4     216      945078428     1007574542
# 2         6     314      845553109      845556915
# 3         7     152     1106635416     1176181731
# 4        10     140     1455301553     1455619275
# ..      ...     ...            ...            ...
# 240     605     221     1277094764     1277177012
# 241     606    1115     1171228846     1368460577
# 242     607     187      963078392      997847387
# 243     608     831     1117161730     1189563917
# 244     610    1302     1479541963     1495959411
#
# [245 rows x 4 columns]

# %%
#Добавляю в объединенную таблицу столбцы с преобразованными датами
df_joined['date_in'] = pd.to_datetime(df_joined['timestamp_max'], unit='s')
df_joined['date_out'] = pd.to_datetime(df_joined['timestamp_min'], unit='s')
df_joined.head()
# Out:
#    userId  rating  timestamp_min  timestamp_max             date_in  \
# 0       1     232      964980499      965719662 2000-08-08 07:27:42
# 1       4     216      945078428     1007574542 2001-12-05 17:49:02
# 2       6     314      845553109      845556915 1996-10-17 12:55:15
# 3       7     152     1106635416     1176181731 2007-04-10 05:08:51
# 4      10     140     1455301553     1455619275 2016-02-16 10:41:15
#
#              date_out
# 0 2000-07-30 18:08:19
# 1 1999-12-13 09:47:08
# 2 1996-10-17 11:51:49
# 3 2005-01-25 06:43:36
# 4 2016-02-12 18:25:53

# %%
# Добавляю столбец со временем жизни пользователя
df_joined['lifetime'] = df_joined.apply(lambda df: df['date_in'] - df['date_out'], axis = 1)
df_joined.head()
# Out:
#    userId  rating  timestamp_min  timestamp_max             date_in  \
# 0       1     232      964980499      965719662 2000-08-08 07:27:42
# 1       4     216      945078428     1007574542 2001-12-05 17:49:02
# 2       6     314      845553109      845556915 1996-10-17 12:55:15
# 3       7     152     1106635416     1176181731 2007-04-10 05:08:51
# 4      10     140     1455301553     1455619275 2016-02-16 10:41:15
#
#              date_out          lifetime
# 0 2000-07-30 18:08:19   8 days 13:19:23
# 1 1999-12-13 09:47:08 723 days 08:01:54
# 2 1996-10-17 11:51:49   0 days 01:03:26
# 3 2005-01-25 06:43:36 804 days 22:25:15
# 4 2016-02-12 18:25:53   3 days 16:15:22

# %%
#Подсчитываю среднее время жизни пользователя
df_joined['lifetime'].mean()
# Out:
# Timedelta('517 days 17:22:47.734693888')

# %%
📘Задание 4

Дана статистика услуг перевозок клиентов компании по типам (см. файл с кодом занятия).
Необходимо сформировать две таблицы:
таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
аналогичную таблицу по типам выручки с указанием адреса клиента
Обратите внимание, что в процессе объединения таблиц данные не должны теряться.

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
#Объединяю таблицу rzd с таблицей auto по столбцу client_id с помощью метода outer
df = rzd.merge(auto, on='client_id', how='outer')
df
# Out:
#    client_id  rzd_revenue  auto_revenue
# 0        111       1093.0           NaN
# 1        112       2810.0           NaN
# 2        113      10283.0       57483.0
# 3        114       5774.0          83.0
# 4        115        981.0         912.0
# 5        116          NaN        4834.0
# 6        117          NaN          98.0

# %%
#Объединяю полученную на предыдущем шаге таблицу с таблицей air
#по столбцу client_id с помощью метода outer
df_joined = df.merge(air, on='client_id', how='outer')
df_joined
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %%
#Заменяю пустые значения в объединенной таблице на 0
df_joined.fillna(0, inplace=True)
df_joined
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           0.0          0.0
# 1        112       2810.0           0.0          0.0
# 2        113      10283.0       57483.0          0.0
# 3        114       5774.0          83.0          0.0
# 4        115        981.0         912.0         81.0
# 5        116          0.0        4834.0          4.0
# 6        117          0.0          98.0         13.0
# 7        118          0.0           0.0        173.0

# %%
#Посчитала итоговую сумму по каждому клиенту
df_joined['total_sum'] = df_joined.apply(lambda df: df['rzd_revenue']+df['auto_revenue']+df['air_revenue'], axis = 1)
#log.loc[log.region == 'Russia', 'VAT'] = 1.2
df_joined
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue  total_sum
# 0        111       1093.0           0.0          0.0     1093.0
# 1        112       2810.0           0.0          0.0     2810.0
# 2        113      10283.0       57483.0          0.0    67766.0
# 3        114       5774.0          83.0          0.0     5857.0
# 4        115        981.0         912.0         81.0     1974.0
# 5        116          0.0        4834.0          4.0     4838.0
# 6        117          0.0          98.0         13.0      111.0
# 7        118          0.0           0.0        173.0      173.0

# %%
#Добавила столбец с адресом
df_joined_with_address = df_joined.merge(client_base, on='client_id', how='outer')
df_joined_with_address
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue  total_sum  \
# 0        111       1093.0           0.0          0.0     1093.0
# 1        112       2810.0           0.0          0.0     2810.0
# 2        113      10283.0       57483.0          0.0    67766.0
# 3        114       5774.0          83.0          0.0     5857.0
# 4        115        981.0         912.0         81.0     1974.0
# 5        116          0.0        4834.0          4.0     4838.0
# 6        117          0.0          98.0         13.0      111.0
# 7        118          0.0           0.0        173.0      173.0
#
#            address
# 0  Комсомольская 4
# 1   Энтузиастов 8а
# 2  Левобережная 1а
# 3          Мира 14
# 4        ЗЖБИиДК 1
# 5    Строителей 18
# 6  Панфиловская 33
# 7     Мастеркова 4

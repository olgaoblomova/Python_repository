# %% [markdown]
# 📘**Домашнее задание к лекции.
#
# Задание 1**
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
#Создаю датафрейм df
df = pd.read_csv('ratings.csv')
#df = pd.read_csv('ml-latest-small\ratings.csv')
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
def classification_of_films(rating):
    """
    Функция классифицирует фильмы по следующим правилам:
        - оценка 2 и меньше - низкий рейтинг (low rating)
        - оценка 4 и меньше - средний рейтинг (average rating)
        - оценка 4.5 и 5 - высокий рейтинг (высокий рейтинг)
    """
    if (rating == 4.5)|(rating == 5):
        return 'high rating'
    elif rating <= 2:
        return 'low rating'
    else:
        return 'average rating'

# %%
# Добавляю столбец class
df['class'] = df['rating'].apply(classification_of_films)
df[500:520]
# Out:
#      userId  movieId  rating   timestamp           class
# 500       4     4226     2.0  1007569424      low rating
# 501       4     4239     5.0   986848685     high rating
# 502       4     4246     4.0  1007574542  average rating
# 503       4     4252     3.0  1007569465  average rating
# 504       4     4260     2.0  1007569424      low rating
# 505       4     4273     4.0  1007574470  average rating
# 506       4     4308     1.0  1007569465      low rating
# 507       4     4347     4.0  1007569586  average rating
# 508       4     4381     3.0  1007574509  average rating
# 509       4     4641     1.0  1007569586      low rating
# 510       4     4741     3.0  1007574532  average rating
# 511       4     4765     5.0  1007569445     high rating
# 512       4     4881     3.0  1007569445  average rating
# 513       4     4896     4.0  1007574532  average rating
# 514       4     4902     4.0  1007569465  average rating
# ...

# %% [markdown]
# 📘Задание 2
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 1
# 2
# 3
# 4
# 5
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
# Создаю датафрейм
df_keywords = pd.read_csv('ml-latest-small\keywords.csv')
df_keywords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   keyword  100000 non-null  object
#  1   shows    100000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
df_keywords.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
def find_city(string):
    """
    Функция возвращает название региона, если строка (поисковый запрос) содержит название
    города региона, в противном случае возвращает 'undefined'.
    """
    geo_data = {
'Центр': ['москва', 'тула', 'ярославль'],
'Северо-Запад': ['петербург', 'псков', 'мурманск'],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}
    for i in string.split(' '):
        if i[:-1] in [el[:-1] for el in geo_data['Центр']]:
            return 'Центр'
        elif (i in geo_data['Северо-Запад'])|(i[:-1] in geo_data['Северо-Запад']):
            return 'Северо-Запад'
        elif (i in geo_data['Дальний Восток'])|(i[:-1] in geo_data['Дальний Восток']):
            return 'Дальний Восток'
        else:
            continue
    return 'undefined'

# %%
#Добавляю столбец 'region'
df_keywords['region'] = df_keywords['keyword'].apply(find_city)
df_keywords.tail()
# Out:
#                        keyword  shows     region
# 99995   эльдорадо старый оскол   3705  undefined
# 99996      frigate для firefox   3630  undefined
# 99997                   укрсиб   3630  undefined
# 99998  погода в ялте на неделю   3688  undefined
# 99999                     ггму   3630  undefined

# %%
#Просмотр данных, в которых в столбце 'region' находится значение отличное от'undefined'
df_keywords[df_keywords['region'] != 'undefined']
# Out:
#                                      keyword   shows        region
# 127                             авито москва  979292         Центр
# 143                               эхо москвы  889657         Центр
# 197                          погода в москве  745745         Центр
# 370                 авито ру санкт петербург  425134  Северо-Запад
# 414               погода в москве на 14 дней  400914         Центр
# ...                                      ...     ...           ...
# 99590  авито ярославль автомобили с пробегом    3673         Центр
# 99597               индексы москвы по адресу    3574         Центр
# 99808      полармед мурманск запись на прием    3719  Северо-Запад
# 99890                    яндекс метро москва    4548         Центр
# 99922                      авто ру ярославль    3712         Центр
#
# [1115 rows x 3 columns]

# %% [markdown]
# 📘Задание 3 (бонусное)
#
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл movies.csv и ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#
# для каждой строки пройдите по всем годам списка years
# если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга

# %%
df = pd.read_csv('ratings.csv')
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_movies = pd.read_csv('ml-latest-small\movies.csv')
df_movies[1000:1020]
# Out:
#       movieId                                              title  \
# 1000     1302                             Field of Dreams (1989)
# 1001     1303                  Man Who Would Be King, The (1975)
# 1002     1304          Butch Cassidy and the Sundance Kid (1969)
# 1003     1305                                Paris, Texas (1984)
# 1004     1306  Until the End of the World (Bis ans Ende der W...
# 1005     1307                     When Harry Met Sally... (1989)
# 1006     1310                                       Hype! (1996)
# 1007     1312                          Female Perversions (1996)
# 1008     1318                                  Blue Juice (1995)
# 1009     1320                     Alien³ (a.k.a. Alien 3) (1992)
# 1010     1321             American Werewolf in London, An (1981)
# 1011     1322            Amityville 1992: It's About Time (1992)
# 1012     1323                              Amityville 3-D (1983)
# ...

# %%
years = [x for x in range(1950,2022)]
print(years)
print(len(years))
# Out:
# [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# 72

# %%
def production_year(string):
    """
    Функция каждой строке из названия фильма выставляет год выпуска
    """
    for i in years:
        if str(i) in string:
            return str(i)
    return '1900'

# %%
#Добавляю столбец 'year' в датафрейм df_movies
df_movies['year'] = df_movies['title'].apply(production_year)
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
# Объединяю таблицу с рейтингами и названиями фильмов по столбцу 'movieId'
df_joined = df.merge(df_movies, on='movieId', how='left')
df_joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                               Comedy|Romance  1995
# 2                        Action|Crime|Thriller  1995
# 3                             Mystery|Thriller  1995
# 4                       Crime|Mystery|Thriller  1995

# %%
#Группирую столбцы по году и нахожу средние значения
df_mean = df_joined.groupby('year').mean().reset_index()
df_mean.head(25)
# Out:
#     year      userId       movieId    rating     timestamp
# 0   1900  337.704522   6298.424460  3.806526  1.164176e+09
# 1   1950  325.291925   4402.739130  3.813665  1.166512e+09
# 2   1951  331.719780   2104.802198  3.804945  1.136664e+09
# 3   1952  356.708333   2687.718750  3.953125  1.156213e+09
# 4   1953  344.398693   4340.869281  3.647059  1.174100e+09
# 5   1954  315.735294   2426.022059  4.009191  1.159430e+09
# 6   1955  353.615385   3942.093407  3.719780  1.136474e+09
# 7   1956  394.295652   4670.304348  3.682609  1.142896e+09
# 8   1957  315.865116   3012.213953  4.039535  1.178092e+09
# 9   1958  341.042424   3267.648485  3.842424  1.114448e+09
# 10  1959  334.958848   2709.139918  3.794239  1.141051e+09
# 11  1960  337.948207   3800.266932  3.721116  1.163617e+09
# 12  1961  323.911111   6044.808889  3.700000  1.161863e+09
# 13  1962  328.343511   4645.015267  3.969466  1.145154e+09
# 14  1963  350.477352   4408.951220  3.628920  1.157645e+09
# ...

# %%
# Сортирую результат по убыванию рейтинга. Похоже, раньше снимали настоящее кино, не то что сейчас..
df_mean.sort_values('rating', ascending=False, inplace=True)
df_mean[['rating', 'year']].head()
# Out:
#       rating  year
# 8   4.039535  1957
# 5   4.009191  1954
# 13  3.969466  1962
# 3   3.953125  1952
# 23  3.944293  1972

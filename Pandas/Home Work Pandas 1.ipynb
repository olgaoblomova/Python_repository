# %%
import pandas as pd

# %% [markdown]
# 📘Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
#Создаю датафрейм df
df = pd.read_csv('ratings.csv')
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#Нахожу ID фильма, которому наибольшее количество пользователей поставило оценку 5.0
df[df.rating == 5.0][['userId','movieId']].groupby('movieId').count().sort_values('userId', ascending = False).head(1)
# Out:
#          userId
# movieId
# 318         153

# %%
dff = pd.read_csv('ml-latest-small\movies.csv')
dff[110:140]
# Out:
#      movieId                                     title  \
# 110      128                     Jupiter's Wife (1994)
# 111      129                     Pie in the Sky (1996)
# 112      132                               Jade (1995)
# 113      135                     Down Periscope (1996)
# 114      137                    Man of the Year (1995)
# 115      140              Up Close and Personal (1996)
# 116      141                      Birdcage, The (1996)
# 117      144             Brothers McMullen, The (1995)
# 118      145                           Bad Boys (1995)
# 119      146       Amazing Panda Adventure, The (1995)
# 120      147            Basketball Diaries, The (1995)
# 121      148          Awfully Big Adventure, An (1995)
# 122      149                            Amateur (1994)
# 123      150                          Apollo 13 (1995)
# 124      151                            Rob Roy (1995)
# 125      152                     Addiction, The (1995)
# ...

# %%
dff_138 = dff[dff['movieId'] == 318]
#dff_138 = dff.query(f'movieId == {318}')
dff_138.head()
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# 📘Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
#Создаю датафрем df
df = pd.read_csv('power.csv')
df.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
#Создаю датафрейм со странами Прибалтики
df_baltics = df[(df['country'] == 'Estonia')|(df['country'] == 'Lithuania')|(df['country'] == 'Latvia')]
df_baltics.head()
# Out:
#        country  year  quantity  category
# 373  Lithuania  2014      39.0         1
# 374  Lithuania  2013     192.0         1
# 375  Lithuania  2012     196.0         1
# 376  Lithuania  2011     171.0         1
# 377  Lithuania  2010     158.0         1

# %%
#Из датафрема со странми Прибалтики оставляю данные удовлетворяющие условию: категории 4, 12 и 21 за период с 2005 по 2010 года, не учитывая в расчетах отрицательные значения quantity.
df_3 = df_baltics[((df_baltics['category'] == 1)|(df_baltics['category'] == 12)|(df_baltics['category'] == 21))&(df_baltics.quantity>=0)&((df_baltics['year']<=2010)&(df_baltics['year']>=2005))]
df_3.head()
# Out:
#        country  year  quantity  category
# 377  Lithuania  2010     158.0         1
# 378  Lithuania  2009     158.0         1
# 379  Lithuania  2008     100.0         1
# 380  Lithuania  2007     105.0         1
# 960  Lithuania  2010       0.0         1

# %%
#Получаю суммарное потребление(столбец 'quantity')
df_3.quantity.sum()
# Out:
# 242679.0

# %% [markdown]
# 📘Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
pd.read_html('http://fortrader.org/quotes')[2]
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0       Золото Цена золота на бирже  1 728      -0.00         -0.00        NaN
# 1  Серебро Цена на серебро на бирже  25.89      -0.03         -0.11        NaN
# 2         Палладий Цена на Палладий  2 358       1.00          0.00        NaN
# 3           Платина Цены на платину  1 209       2.00          0.00        NaN
# 4           Медь Цена меди на бирже   4.15      -0.00         -0.05        NaN

# %%
pd.read_html('https://www.banki.ru/banks/ratings/')[0]
# Out:
#     место                  название банка лицензия №, Регион  \
#     место                  название банка лицензия №, Регион
# 0       1            СберБанк лицензия № 1481, Москва и обл.
# 1       2        ВТБ лицензия № 1000, Санкт-Петербург и обл.
# 2       3          Газпромбанк лицензия № 354, Москва и обл.
# 3       4  Национальный Клиринговый Центр лицензия № 3466...
# 4       5          Альфа-Банк лицензия № 1326, Москва и обл.
# 5       6      Россельхозбанк лицензия № 3349, Москва и обл.
# 6       7  Московский Кредитный Банк лицензия № 1978, Мос...
# 7       8       Банк Открытие лицензия № 2209, Москва и обл.
# 8       9        Совкомбанк лицензия № 963, Костромская обл.
# 9   10 +3         ЮниКредит Банк лицензия № 1, Москва и обл.
# 10  11 −1      Райффайзенбанк лицензия № 3292, Москва и обл.
# 11     12             Росбанк лицензия № 2272, Москва и обл.
# 12  13 −2               Траст лицензия № 3279, Москва и обл.
# ...

# %%
#Или так
pd.read_html('https://www.banki.ru/banks/ratings/', attrs = {'class': 'standard-table standard-table--row-highlight margin-bottom-small margin-top-x-small'})[0]
# Out:
#     место                  название банка лицензия №, Регион  \
#     место                  название банка лицензия №, Регион
# 0       1            СберБанк лицензия № 1481, Москва и обл.
# 1       2        ВТБ лицензия № 1000, Санкт-Петербург и обл.
# 2       3          Газпромбанк лицензия № 354, Москва и обл.
# 3       4  Национальный Клиринговый Центр лицензия № 3466...
# 4       5          Альфа-Банк лицензия № 1326, Москва и обл.
# 5       6      Россельхозбанк лицензия № 3349, Москва и обл.
# 6       7  Московский Кредитный Банк лицензия № 1978, Мос...
# 7       8       Банк Открытие лицензия № 2209, Москва и обл.
# 8       9        Совкомбанк лицензия № 963, Костромская обл.
# 9   10 +3         ЮниКредит Банк лицензия № 1, Москва и обл.
# 10  11 −1      Райффайзенбанк лицензия № 3292, Москва и обл.
# 11     12             Росбанк лицензия № 2272, Москва и обл.
# 12  13 −2               Траст лицензия № 3279, Москва и обл.
# ...

# %%
# Еще одна таблица
pd.read_html('http://www.vnukovo.ru/flights/online-timetable/')[0]
# Out:
#                    0        1         2                        3    4  \
# 0    00:0513.03.2021  ZF 8839  АЗУР ЭЙР           Мале (Интерн.)    А
# 1    00:0513.03.2021   ЮТ 351     Utair           Ханты-Мансийск    А
# 2    00:1513.03.2021  РГ 4559   РусЛайн                Махачкала    А
# 3    00:1513.03.2021   ЮТ 559     Utair                Махачкала    А
# 4    00:4013.03.2021   ДР 449    Победа                   Тюмень    А
# ..               ...      ...       ...                      ...  ...
# 137  23:5013.03.2021   ДР 495    Победа                   Курган    А
# 138  23:5013.03.2021   ЮТ 453     Utair                   Тюмень    А
# 139  23:5513.03.2021   ДР 405    Победа  Екатеринбург (Кольцово)    А
# 140  23:5513.03.2021   ДР 413    Победа    Челябинск (Баландино)    А
# 141              NaN      NaN       NaN                      NaN  NaN
#
#                                                     5
# 0                              Совершил посадку 08:13
# ...
